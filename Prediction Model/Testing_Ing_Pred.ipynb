# %% [markdown]
# # Import Packages

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

print("Import Successful")
# Out:
# 2024-04-26 07:02:32.350896: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 07:02:32.351044: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 07:02:32.519011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Import Successful

# %% [markdown]
# # Load Model

# %%
cnn = tf.keras.models.load_model("/kaggle/input/ingredient-detection/keras/v1/1/trained_model.h5")

# %% [markdown]
# # Single Image Prediction

# %%
import cv2
image_path = "/kaggle/input/fruit-and-vegetable-image-recognition/test/beetroot/Image_3.jpg"
img = cv2.imread(image_path)
plt.imshow(img)
plt.title("Test Image")
plt.xticks([])
plt.yticks([])
plt.show()
